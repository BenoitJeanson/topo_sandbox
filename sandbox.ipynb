# %%
import grid2op
# create an environment
env_name = "rte_case14_realistic"  # for example, other environments might be usable
env = grid2op.make(env_name)
# Out:
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)

# %%
import pypowsybl

# %%
# create an agent
from grid2op.Agent import RandomAgent
my_agent = RandomAgent(env.action_space)

# proceed as you would any open ai gym loop
nb_episode = 10
for _ in range(nb_episode):
    # you perform in this case 10 different episodes
    obs = env.reset()
    reward = env.reward_range[0]
    done = False
    while not done:
        # here you loop on the time steps: at each step your agent receive an observation
        # takes an action
        # and the environment computes the next observation that will be used at the next step.
        act = my_agent.act(obs, reward, done)
        obs, reward, done, info = env.step(act)
# Out:
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)
#
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)

# %%
import pandapower as pp
pp_grid = pp.from_json('./grid.json')
# Out:
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/io_utils.py:509: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(self.obj, precise_float=True, convert_axes=False, **self.d)

# %%
dir(pp_grid)
# Out:
# ['OPF_converged',
#  '_empty_res_asymmetric_load',
#  '_empty_res_asymmetric_load_3ph',
#  '_empty_res_asymmetric_sgen',
#  '_empty_res_asymmetric_sgen_3ph',
#  '_empty_res_bus',
#  '_empty_res_bus_3ph',
#  '_empty_res_dcline',
#  '_empty_res_ext_grid',
#  '_empty_res_ext_grid_3ph',
#  '_empty_res_gen',
#  '_empty_res_impedance',
#  '_empty_res_line',
#  '_empty_res_line_3ph',
#  '_empty_res_load',
#  '_empty_res_load_3ph',
#  '_empty_res_motor',
#  '_empty_res_sgen',
#  '_empty_res_sgen_3ph',
#  '_empty_res_shunt',
#  '_empty_res_storage',
#  '_empty_res_storage_3ph',
#  '_empty_res_svc',
#  '_empty_res_switch',
#  '_empty_res_tcsc',
#  '_empty_res_trafo',
#  '_empty_res_trafo3w',
#  '_empty_res_trafo_3ph',
#  '_empty_res_ward',
#  '_empty_res_xward',
#  '_is_elements',
#  '_pd2ppc_lookups',
#  '_ppc',
#  '_ppc0',
#  '_ppc1',
#  '_ppc2',
#  'asymmetric_load',
#  'asymmetric_sgen',
#  'bus',
#  'bus_geodata',
#  'characteristic',
#  'controller',
#  'converged',
#  'dcline',
#  'ext_grid',
#  'f_hz',
#  'format_version',
#  'gen',
#  'group',
#  'impedance',
#  'line',
#  'line_geodata',
#  'load',
#  'measurement',
#  'motor',
#  'name',
#  'poly_cost',
#  'pwl_cost',
#  'res_asymmetric_load',
#  'res_asymmetric_load_3ph',
#  'res_asymmetric_sgen',
#  'res_asymmetric_sgen_3ph',
#  'res_bus',
#  'res_bus_3ph',
#  'res_bus_est',
#  'res_bus_sc',
#  'res_dcline',
#  'res_ext_grid',
#  'res_ext_grid_3ph',
#  'res_ext_grid_sc',
#  'res_gen',
#  'res_gen_sc',
#  'res_impedance',
#  'res_impedance_est',
#  'res_line',
#  'res_line_3ph',
#  'res_line_est',
#  'res_line_sc',
#  'res_load',
#  'res_load_3ph',
#  'res_motor',
#  'res_sgen',
#  'res_sgen_3ph',
#  'res_sgen_sc',
#  'res_shunt',
#  'res_shunt_3ph',
#  'res_storage',
#  'res_storage_3ph',
#  'res_svc',
#  'res_switch',
#  'res_switch_est',
#  'res_switch_sc',
#  'res_tcsc',
#  'res_trafo',
#  'res_trafo3w',
#  'res_trafo3w_est',
#  'res_trafo3w_sc',
#  'res_trafo_3ph',
#  'res_trafo_est',
#  'res_trafo_sc',
#  'res_ward',
#  'res_xward',
#  'sgen',
#  'shunt',
#  'sn_mva',
#  'std_types',
#  'storage',
#  'svc',
#  'switch',
#  'tcsc',
#  'trafo',
#  'trafo3w',
#  'user_pf_options',
#  'version',
#  'ward',
#  'xward']

# %%
pp.runpp(pp_grid)
# Out:
# numba cannot be imported and numba functions are disabled.
# Probably the execution is slow.
# Please install numba to gain a massive speedup.
# (or if you prefer slow execution, set the flag numba=False to avoid this warning!)

# %%
pp.plotting.simple_plot(pp_grid, plot_loads=True, plot_gens=True)
# Out:
# No or insufficient geodata available --> Creating artificial coordinates. This may take some time
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /Users/benoitjeanson/vsCode/TUD/topo_sandbox/sandbox.ipynb Cellule 7 line 1
# ----> <a href='vscode-notebook-cell:/Users/benoitjeanson/vsCode/TUD/topo_sandbox/sandbox.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> pp.plotting.simple_plot(pp_grid, plot_loads=True, plot_gens=True)
#
# File ~/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/plotting/simple_plot.py:107, in simple_plot(net, respect_switches, line_width, bus_size, ext_grid_size, trafo_size, plot_loads, plot_gens, plot_sgens, load_size, gen_size, sgen_size, switch_size, switch_distance, plot_line_switches, scale_size, bus_color, line_color, dcline_color, trafo_color, ext_grid_color, switch_color, library, show_plot, ax)
#     104 if len(net.line_geodata) == 0 and len(net.bus_geodata) == 0:
#     105     logger.warning("No or insufficient geodata available --> Creating artificial coordinates." +
#     106                    " This may take some time")
# --> 107     create_generic_coordinates(net, respect_switches=respect_switches, library=library)
#     109 if scale_size:
#     110     # if scale_size -> calc size from distance between min and max geocoord
#     111     sizes = get_collection_sizes(net, bus_size, ext_grid_size, trafo_size,
#     112                                  load_size, sgen_size, switch_size, switch_distance, gen_size)
#
# File ~/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/plotting/generic_geodata.py:194, in create_generic_coordinates(net, mg, library, respect_switches, geodata_table, buses, overwrite)
#     192 if library == "igraph":
#     193     if not IGRAPH_INSTALLED:
# --> 194         soft_dependency_error("build_igraph_from_pp()", "python-igraph")
#     195     graph, meshed, roots = build_igraph_from_pp(net, respect_switches, buses=buses)
#     196     coords = coords_from_igraph(graph, roots, meshed)
#
# File ~/vsCode/TUD/topo_sandbox/.venv/lib/python3.11/site-packages/pandapower/auxiliary.py:66, in soft_dependency_error(fct_name, required_packages)
#      63 def soft_dependency_error(fct_name, required_packages):
#      64     required_packages = required_packages if isinstance(required_packages, str) else \
#      65         "','".join(required_packages)
# ---> 66     raise ImportError("Some pandapower functionality use modules outside the setup.py "
#      67                       f"requirements: {fct_name} requires '{required_packages}'. \n"
#      68                       f"{required_packages} could not be imported.\n"
#      69                       "To install all pandapower dependencies, "
#      70                       'pip install pandapower["all"] can be used.')
#
# ImportError: Some pandapower functionality use modules outside the setup.py requirements: build_igraph_from_pp() requires 'python-igraph'.
# python-igraph could not be imported.
# To install all pandapower dependencies, pip install pandapower["all"] can be used.

# %%
# Out:
# Les cellules en cours d’exécution avec .venv nécessitent le package ipykernel.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/benoitjeanson/vsCode/TUD/topo/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
